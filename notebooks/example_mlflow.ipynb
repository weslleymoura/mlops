# %% [markdown]
# # Exemplo rápido: registrar experimento no MLflow

# %%
import mlflow
import mlflow.sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

mlflow.set_tracking_uri('http://localhost:5000')
mlflow.set_experiment('example-iris')

iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state=42)

with mlflow.start_run():
 clf = RandomForestClassifier(n_estimators=10)
 clf.fit(X_train, y_train)
 acc = clf.score(X_test, y_test)
 mlflow.log_metric('accuracy', acc)
 mlflow.sklearn.log_model(clf, 'model')
 print('Accuracy:', acc)
# Out:
# A execução de células com 'Python 3.11.2' requer o pacote ipykernel.
#
# Instale 'ipykernel' no ambiente Python.
#
# Comando: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
